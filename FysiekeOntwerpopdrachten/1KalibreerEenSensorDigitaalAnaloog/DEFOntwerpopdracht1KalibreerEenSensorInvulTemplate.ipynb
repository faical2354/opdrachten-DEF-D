# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 58     |  |
# | :-------------|:-------------|
# |Merel van der Eb| 6408214 |
# | Thijmen Haverkorn van Rijsewijk | 6500897 |
# | Faical Abakouy| 5554462 |
#
# | Planning Groep: 58     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 12.45 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 15.00 |
# | Pauze | 12.45-13.45 |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](schets1.jpeg "analyse: ideeen")
# ![Alt](schets2.jpeg "analyse: ideeen")
# ![Alt](schets3.jpeg "analyse: ideeen")
# ![Alt](schets4.jpeg "analyse: ideeen")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat. **Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |Fluxsensor | toerenteller | Deze sensor de resultaten worden omgezet in Radialen per Seconden.|
# ||| binnen 120 en 12000 rad/s met een afwijking van 5%|
# |Temperatuursensor | drinkbare thee | Binnen 57 en 63 graden Celsius kunnen bepalen
# ||| deze meting heeft een afwijking van 0.5 graden Celsius|
# |krachtsensor | knijpertest | knijpkracht bepalen tussen 10 en 40 Newton
# ||| de sensor heeft een resolutie van 5 Newton |
#
# Groep 58 heeft gekozen voor sensor fluxsensor.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# In deze deze schets is er een accuboor met een niet-metale plaat. Deze plaat heeft langs de rand één magneet. Deze magneet gaat na iedere rotatie langs de fluxsensor. De fluxsensor meting gaan naar de computer en voor iedere peak in de lezing is er 1 rotatie gedaan.
#  ![Alt](opstelling_schets.jpeg "schets student")

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen?
#     moment en snelheid van de magneet
# 2. Over welk bereik ga je deze variabelen veranderen?
#     42-178 rad/s
# 3. Wat ga je allemaal meten?
#     we meten flux en rekenen dat om naar een toerental
# 4. Hoeveel metingen ga je doen?
#     we gaan meten op 3 verschillende standen, iedere stand 2 keer dat zal dan in heoksnelheid variëren
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?
#     ja, we kijken of er flux gegerenereert wordt en de data snel wordt doorgegeven. echter is bij deze proef de waarde van de flux verwaarloosbaar. alleen de stijgingen en dalingen zijn van belang. Ook wordt er in slowmotion gefilmd ter controlering.

# %% [markdown]
# Stappenplan:
# 1. Check of de opstelling klopt
# 2. Zet de slow motion camera en boor tergelijkertijd aan.
# 3. meet op drie verschillende snelheden en herhaal deze metingen 2 keer
# 4. Exporteer data in een cvs bestand
# 5. verwerk de data in een grafiek en maak fits en errorbars

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# De meetopstelling is zoals in de schets. De sensor in de breadboard is verhoogd met een doos zodat de magneet er beter langs draait.
#  ![Alt](opstelling.jpeg "meetopstelling student")
#  ![Alt](GRAF2.jpeg "meetopstelling student")
#  Deze grafiek plot RPM tegen tijd en er is een duidelijk blik dat hij nauwkeurig de rotaties kan meten tot een maximum van 1940 RPM
#  ![Alt](GRAF1.jpeg "meetopstelling student")

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

flux = np.array([486, 489, 492, 477, 479])
rpm = np.array([212, 379, 930, 1391, 1803])

# %%
plt.scatter(rpm, flux, color='green', label='ruwe data')
plt.plot(rpm,flux,'r--',label='fit data punten')
plt.title("Caslibratie grafiek")
plt.xlabel('rpm')
plt.ylabel('flux')
plt.ylim(0,1000)
plt.legend()

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# Het mechanisme was meteen goed tijdens de eerste iteratie. De code is 1 keer veranderd.
#
# De arduino kan uitzichzelf niet een milliseconden bijhouden doordat het 16-bits is. door unsigned long te gebruiken hadden toegang tot 32-bit dat gaf ons toegang om te meten in milliseconden. door dit verschil zijn de pieken beter uitelkaar te houden als de rotatiesnelheid verhoogd.

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Met een analoge sensor is een digitale lezing mogelijk en daadwerkelijk bruikbaar. Het mechanisme wat gevormd is meet het toerental door middel van de fluxmeting van een magneet op het wiel. Deze metingen wwordt gedubbelchecked met een een slowmotion camera. Dankzij deze camera en het verwerken van de data in python, weten we dat onze meting binnen de foutmarge zit.
#
#
# De meting van de boor wordt instabiel zodra de boor maximaal benut wordt. Dit is een zodra het een toerental hoger haald dan 2000 wat de maximale toerental is van de boor volgens de Praxis. Hij wordt steeds minder nauwkeurig op het filmpje omdat het lastiger wordt om de toeren handmatig te tellen omdat de toeren sneller gaan dan de fps. Handmatig is er een nauwkeurigheid van 0.8% bij lage toeren, maar 5% bij hogen toeren vanwege de hiervoor benoemde reden. De arduino meet bij een hoge toerental een nauwkeurigheid van 0.72%.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# De meetopstelling is zoals in de schets. De sensor in de breadboard is verhoogd met een doos zodat de magneet er beter langs draait.
#  ![Alt](opstelling.jpeg "meetopstelling student")

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat. **Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |Fluxsensor | toerenteller | Deze sensor de resultaten worden omgezet in Radialen per Seconden.|
# ||| binnen 20 en 60 rad/s met een afwijking van 5 rad/s|
# |Temperatuursensor | drinkbare thee | Binnen 57 en 63 graden Celsius kunnen bepalen
# ||| deze meting heeft een afwijking van 0.5 graden Celsius|
# |krachtsensor | knijpertest | knijpkracht bepalen tussen 10 en 40 Newton
# ||| de sensor heeft een resolutie van 5 Newton |
#
# Groep 58 heeft gekozen voor sensor fluxsensor.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# Met een analoge sensor is een digitale lezing mogelijk en daadwerkelijk bruikbaar. Het mechanisme wat gevormd is meet het toerental door middel van de fluxmeting van een magneet op het wiel. Deze metingen wwordt gedubbelchecked met een een slowmotion camera. Dankzij deze camera en het verwerken van de data in python, weten we dat onze meting binnen de foutmarge zit.
#
#
# De meting van de boor wordt instabiel zodra de boor maximaal benut wordt. Dit is een zodra het een toerental hoger haald dan 2000 wat de maximale toerental is van de boor volgens de Praxis. Hij wordt steeds minder nauwkeurig op het filmpje omdat het lastiger wordt om de toeren handmatig te tellen omdat de toeren sneller gaan dan de fps. Handmatig is er een nauwkeurigheid van 0.8% bij lage toeren, maar 5% bij hogen toeren vanwege de hiervoor benoemde reden. De arduino meet bij een hoge toerental een nauwkeurigheid van 0.72%.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

flux = np.array([486, 489, 492, 477, 479])
rpm = np.array([212, 379, 930, 1391, 1803])

plt.scatter(rpm, flux, color='green', label='ruwe data')
plt.plot(rpm,flux,'r--',label='fit data punten')
plt.title("Caslibratie grafiek")
plt.xlabel('rpm')
plt.ylabel('flux')
plt.ylim(0,1000)
plt.legend()

# %% [markdown]
# De meetopstelling is zoals in de schets. De sensor in de breadboard is verhoogd met een doos zodat de magneet er beter langs draait.
#  ![Alt](opstelling.jpeg "meetopstelling student")
